# %% [markdown]
# # Introduction to Pandas
#
# ### What are we going to learn:
# - Import spreadsheet into pandas
# - Convert it into a dataframe
# - Sort the data
# - Clean/filter the data
# - return a portion of the data answering the question: "What were the highest grossing movies?"

# %%
import pandas as pd

# %%
excel_file = 'movies.xls'
excel_file
# Out:
# 'movies.xls'

# %%
movies = pd.read_excel(excel_file)
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
movies_sheet1 = pd.read_excel(excel_file, sheet_name=0, index_col=0)
movies_sheet2 = pd.read_excel(excel_file, sheet_name=1, index_col=0)
movies_sheet3 = pd.read_excel(excel_file, sheet_name=2, index_col=0)

# %%
movies = pd.concat([movies_sheet1, movies_sheet2, movies_sheet3])

# %%
movies.shape
# Out:
# (5042, 24)

# %%
movies.drop_duplicates(inplace=True)

# %%
movies
# Out:
#                                                      Year  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916.0
# Over the Hill to the Poorhouse                     1920.0
# The Big Parade                                     1925.0
# Metropolis                                         1927.0
# Pandora's Box                                      1929.0
# ...                                                   ...
# War & Peace                                           NaN
# Wings                                                 NaN
# Wolf Creek                                            NaN
# Wuthering Heights                                     NaN
# Yu-Gi-Oh! Duel Monsters                               NaN
#
#                                                                                       Genres  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                           Drama|History|War
# ...

# %%
sorted_by_gross = movies.sort_values(["Gross Earnings"], ascending=False)

# %%
sorted_by_gross.head()
# Out:
#                     Year                            Genres Language Country  \
# Title
# Avatar            2009.0   Action|Adventure|Fantasy|Sci-Fi  English     USA
# Titanic           1997.0                     Drama|Romance  English     USA
# Jurassic World    2015.0  Action|Adventure|Sci-Fi|Thriller  English     USA
# The Avengers      2012.0           Action|Adventure|Sci-Fi  English     USA
# The Dark Knight   2008.0       Action|Crime|Drama|Thriller  English     USA
#
#                  Content Rating  Duration  Aspect Ratio       Budget  \
# Title
# Avatar                    PG-13     178.0          1.78  237000000.0
# Titanic                   PG-13     194.0          2.35  200000000.0
# Jurassic World            PG-13     124.0          2.00  150000000.0
# The Avengers              PG-13     173.0          1.85  220000000.0
# The Dark Knight           PG-13     152.0          2.35  185000000.0
#
#                   Gross Earnings           Director  ...  \
# ...

# %%
import matplotlib
matplotlib.use("Agg")

import matplotlib.pyplot as plt

# %%
sorted_by_gross.head().plot(kind="barh")
# %matplotlib inline
plt.show()

# %%
plt.savefig("/home/student/static/stackedbar.png", bbox_inches='tight')
